# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalpan1104/SQL-Data-Warehousing-Project/blob/main/Scripts/init_databse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
db_file = 'Data Warehousing.db'
try:
    conn = sqlite3.connect(db_file)
    print(f"Successfully created/connected to database: {db_file}")

except sqlite3.Error as e:
    print(f"An error occurred: {e}")
finally:
    if conn:
        conn.close()
        print("Database connection closed.")
# Out:
# Successfully created/connected to database: Data Warehousing.db
# Database connection closed.

# %%
print("Hi")
# Out:
# Hi
